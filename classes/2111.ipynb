# %%
from pycaret.datasets import get_data
from pycaret.classification import setup

# %%
# ?get_data

# %%
df = get_data("diabetes", verbose=False)

# %%
s = setup(df, target = 'Class variable')
# Out:
# <style type="text/css">
# #T_81e56_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_81e56">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_81e56_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_81e56_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_81e56_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_81e56_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_81e56_row0_col1" class="data row0 col1" >6771</td>
#     </tr>
#     <tr>
#       <th id="T_81e56_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_81e56_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_81e56_row1_col1" class="data row1 col1" >Class variable</td>
#     </tr>
#     <tr>
#       <th id="T_81e56_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
best_model = s.compare_models()
# Out:
# <style type="text/css">
# #T_27c90 th {
#   text-align: left;
# }
# ...

# %%
catboost_model = s.create_model("catboost", depth=9)
# Out:
# <style type="text/css">
# #T_ebec3_row10_col0, #T_ebec3_row10_col1, #T_ebec3_row10_col2, #T_ebec3_row10_col3, #T_ebec3_row10_col4, #T_ebec3_row10_col5, #T_ebec3_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_ebec3">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ebec3_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_ebec3_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_ebec3_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_ebec3_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_ebec3_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_ebec3_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_ebec3_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
# ...

# %%
type(best_model)
# Out:
# sklearn.ensemble._forest.ExtraTreesClassifier

# %%
s.evaluate_model(best_model)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
saved_model, model_path = s.save_model(best_model, "my_best_model")
# Out:
# Transformation Pipeline and Model Successfully Saved

# %%
saved_model
# Out:
# Pipeline(memory=Memory(location=C:\Users\s20460\AppData\Local\Temp\joblib),
#          steps=[('numerical_imputer',
#                  TransformerWrapper(exclude=None,
#                                     include=['Number of times pregnant',
#                                              'Plasma glucose concentration a 2 '
#                                              'hours in an oral glucose '
#                                              'tolerance test',
#                                              'Diastolic blood pressure (mm Hg)',
#                                              'Triceps skin fold thickness (mm)',
#                                              '2-Hour serum insulin (mu U/ml)',
#                                              'Body mass index (weight in...
#                  ExtraTreesClassifier(bootstrap=False, ccp_alpha=0.0,
#                                       class_weight=None, criterion='gini',
# ...

# %%
s.pipeline
# Out:
# Pipeline(memory=Memory(location=C:\Users\s20460\AppData\Local\Temp\joblib),
#          steps=[('numerical_imputer',
#                  TransformerWrapper(exclude=None,
#                                     include=['Number of times pregnant',
#                                              'Plasma glucose concentration a 2 '
#                                              'hours in an oral glucose '
#                                              'tolerance test',
#                                              'Diastolic blood pressure (mm Hg)',
#                                              'Triceps skin fold thickness (mm)',
#                                              '2-Hour serum insulin (mu U/ml)',
#                                              'Body mass index (weight in...
#                                                               verbose='deprecated'))),
#                 ('categorical_imputer',
#                  TransformerWrapper(exclude=None, include=[],
# ...
